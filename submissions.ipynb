# %% [markdown]
# <div align="center">
#
# # M2PF Submission
#
# <div align="center">
#
# ## Michiel Nys

# %%
import pandas as pd
import numpy as np

# %%
X_train = pd.read_csv("X_train.csv")
y_train = pd.read_csv("y_train.csv")
X_test = pd.read_csv("X_test.csv")
print(X_train.head)
# Out:
# <bound method NDFrame.head of         ROW_ID         TS     ALLOCATION    RET_20    RET_19    RET_18  \
# 0            0  DATE_0001  ALLOCATION_01 -0.018192 -0.000306 -0.006881
# 1            1  DATE_0001  ALLOCATION_02 -0.006394 -0.001059  0.001565
# 2            2  DATE_0001  ALLOCATION_03 -0.016587 -0.004517 -0.005306
# 3            3  DATE_0001  ALLOCATION_04 -0.005344  0.002790  0.006937
# 4            4  DATE_0001  ALLOCATION_05 -0.010506 -0.005491  0.007752
# ...        ...        ...            ...       ...       ...       ...
# 527068  527068  DATE_2522  ALLOCATION_95 -0.000550  0.001751  0.002035
# 527069  527069  DATE_2522  ALLOCATION_96  0.003501 -0.004601 -0.001739
# 527070  527070  DATE_2522  ALLOCATION_97  0.005201  0.000580 -0.001607
# 527071  527071  DATE_2522  ALLOCATION_98 -0.000110  0.000371  0.000852
# 527072  527072  DATE_2522  ALLOCATION_99 -0.000386  0.001714 -0.000599
#
#           RET_17    RET_16    RET_15    RET_14  ...  SIGNED_VOLUME_8  \
# ...
